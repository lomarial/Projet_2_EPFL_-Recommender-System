# %%
# Useful starting lines
# %matplotlib inline

import numpy as np
import scipy
import scipy.io
import scipy.sparse as sp
import matplotlib.pyplot as plt
from helpers import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers import load_data, preprocess_data

path_dataset = "data_train.csv"
ratings = load_data(path_dataset)
path_test="sampleSubmission.csv"
test_submission=load_data(path_test)
# Out:
# number of items: 10000, number of users: 1000
# number of items: 10000, number of users: 1000

# %% [markdown]
# ## Split data

# %%
def split_data(ratings, num_items_per_user, num_users_per_item,
               min_num_ratings, p_test=0.1):
    """split the ratings to training data and test data.
    Args:
        min_num_ratings: 
            all users and items we keep must have at least min_num_ratings per user and per item. 
    """
    # set seed
    np.random.seed(2019)
    
    # select user and item based on the condition.
    valid_users = np.where(num_items_per_user >= min_num_ratings)[0]
    valid_items = np.where(num_users_per_item >= min_num_ratings)[0]
    valid_ratings = ratings[valid_items, :][: , valid_users]  
    
    # init
    num_rows, num_cols = valid_ratings.shape
    train = sp.lil_matrix((num_rows, num_cols))
    test = sp.lil_matrix((num_rows, num_cols))
    
    print("the shape of original ratings. (# of row, # of col): {}".format(
        ratings.shape))
    print("the shape of valid ratings. (# of row, # of col): {}".format(
        (num_rows, num_cols)))

    nz_items, nz_users = valid_ratings.nonzero()
   
    # split the data
    for user in set(nz_users):
        # randomly select a subset of ratings
        row, col = valid_ratings[:, user].nonzero()
        selects = np.random.choice(row, size=int(len(row) * p_test))
        residual = list(set(row) - set(selects))

        # add to train set
        train[residual, user] = valid_ratings[residual, user]

        # add to test set
        test[selects, user] = valid_ratings[selects, user]

    print("Total number of nonzero elements in origial data:{v}".format(v=ratings.nnz))
    print("Total number of nonzero elements in train data:{v}".format(v=train.nnz))
    print("Total number of nonzero elements in test data:{v}".format(v=test.nnz))
    return valid_ratings, train, test

# %% [markdown]
# ## Global mean

# %%
from helpers import calculate_mse

def baseline_global_mean(train):
    """baseline method: use the global mean."""
    # find the non zero ratings in the train
    nonzero_train = train[train.nonzero()]

    # calculate the global mean
    global_mean_train = nonzero_train.mean()
    # predict the ratings as global mean
    mse = calculate_mse(nonzero_train.todense(), global_mean_train)
    rmse = np.sqrt(1.0 * mse / nonzero_train.todense().shape[1])
    print("test RMSE of baseline using the global mean: {v}.".format(v=rmse))
    return global_mean_train
global_mean_train=baseline_global_mean(ratings)
# Out:
# test RMSE of baseline using the global mean: [[1.11905673]].

# %%
num_items, num_users = test_submission.shape
prediction_globalmean=np.array([])
for item_user in range(num_users):
    test=test_submission[:,item_user]
    row,col=test.nonzero()
    prediction_globalmean=np.append(prediction_globalmean,global_mean_train*np.ones((1,len(row))))

# %%
from helpers import *
OUTPUT_PATH = 'global_mean.csv' 

prediction_globalmean=np.round(prediction_globalmean.flatten())


submission(path_test,prediction_globalmean,OUTPUT_PATH)

# %% [markdown]
# ## User mean

# %%
def baseline_user_mean(ratings,test_submission):
    """baseline method: use the user means as the prediction."""
    mse = 0
    num_items, num_users = ratings.shape
    prediction=np.array([])
    for user_index in range(num_users):
        # find the non-zero ratings for each user in the training dataset
        train_ratings = ratings[:, user_index]
        nonzeros_train_ratings = train_ratings[train_ratings.nonzero()]
        
        # calculate the mean if the number of elements is not 0
        if nonzeros_train_ratings.shape[0] != 0:
            user_train_mean = nonzeros_train_ratings.mean()
        else:
            continue
        
        # find the non-zero ratings for each user in the test dataset
        test_ratings = test_submission[:, user_index]
       
       
        prediction=np.append(prediction,user_train_mean*np.ones(test_ratings.nnz))
       
    return prediction
prediction_usermean=baseline_user_mean(ratings, test_submission)

# %%
OUTPUT_PATH = 'user_mean.csv' 

prediction_usermean=np.round(prediction_usermean.flatten())


submission(path_test,prediction_usermean,OUTPUT_PATH)

# %% [markdown]
# ## Item mean

# %%
def baseline_item_mean(train):
    """baseline method: use item means as the prediction."""
    mse = 0
    num_items, num_users = train.shape
    a=np.array([])
    for item_index in range(num_items):
        # find the non-zero ratings for each item in the training dataset
        train_ratings = train[item_index, :]
        nonzeros_train_ratings = train_ratings[train_ratings.nonzero()]
        # calculate the mean if the number of elements is not 0
        if nonzeros_train_ratings.shape[0] != 0:
            item_train_mean = nonzeros_train_ratings.mean()
        else:
            continue
        
        a=np.append(a,item_train_mean)
    return a 
mean_movie=baseline_item_mean(ratings)

# %%
num_items, num_users = test_submission.shape
prediction_item=np.array([])
for item_user in range(num_users):
    test=test_submission[:,item_user]
    row,col=test.nonzero()
    prediction_item=np.append(prediction_item,mean_movie[row])

# %%
OUTPUT_PATH = 'item_mean.csv' 

prediction_item=np.round(prediction_item.flatten())


submission(path_test,prediction_item,OUTPUT_PATH)

# %% [markdown]
# ## Matrix Factorization using SGD

# %%
def init_MF(train, num_features):
    """init the parameter for matrix factorization."""
   
    #  return:
    #     user_features: shape = num_features, num_user
    #     item_features: shape = num_features, num_item
    # ***************************************************
    num_item, num_user = train.get_shape()

    user_features = np.random.rand(num_features, num_user)
    item_features = np.random.rand(num_features, num_item)

    # start by item features.
    item_nnz = train.getnnz(axis=1)
    item_sum = train.sum(axis=1)

    for ind in range(num_item):
        item_features[0, ind] = item_sum[ind, 0] / item_nnz[ind]
    return user_features, item_features

# %%
def compute_error(data, user_features, item_features, nz):
    """compute the loss (MSE) of the prediction of nonzero elements."""
    # ***************************************************
    # calculate rmse (we only consider nonzero entries.)
    # ***************************************************
    mse = 0
    for row, col in nz:
        item_info = item_features[:, row]
        user_info = user_features[:, col]
        mse += (data[row, col] - user_info.T.dot(item_info)) ** 2
    return np.sqrt(1.0 * mse / len(nz))

# %%
def matrix_factorization_SGD(train, test, gamma, num_features, num_epochs,lambda_item, lambda_user):
    """matrix factorization by SGD.
    num_features  K in the lecture notes(number of features for our matrices)
    num_epochs      number of full passes through the train set
    lambda_user , lambda_item : regularization parameters
    """
    
    errors = [0]
    
    # set seed
    np.random.seed(2019)

    # init matrix
    user_features, item_features = init_MF(train, num_features)
    
    # find the non-zero ratings indices 
    nz_row, nz_col = train.nonzero()
    nz_train = list(zip(nz_row, nz_col))
    nz_row, nz_col = test.nonzero()
    nz_test = list(zip(nz_row, nz_col))

    print("learn the matrix factorization using SGD...")
    for it in range(num_epochs):        
        # shuffle the training rating indices
        np.random.shuffle(nz_train)
        
        # decrease step size
        gamma /= 1.2
        
        for d, n in nz_train:
            # update W_d (item_features[:, d]) and Z_n (user_features[:, n])
            item_info = item_features[:, d]
            user_info = user_features[:, n]
            err = train[d, n] - user_info.T.dot(item_info)
    
            # calculate the gradient and update
            item_features[:, d] += gamma * (err * user_info - lambda_item * item_info)
            user_features[:, n] += gamma * (err * item_info - lambda_user * user_info)

        rmse = compute_error(train, user_features, item_features, nz_train)
        print("iter: {}, RMSE on training set: {}.".format(it, rmse))
        # evaluate the test error
        rmse = compute_error(test, user_features, item_features, nz_test)
        print("RMSE on test data: {}.".format(rmse))

        errors.append(rmse)
    return errors,item_features,user_features

# %%
def hyper_par(train, test, gammas, Ks, lambdas_user, lambdas_item, num_epochs):
    '''
    This method allow us to get the best hyper parameters
    :return: the best combination of parameters with the lowest rmse
    '''
    errors = {}
    for g in gammas:
        for k in Ks:
            for lambda_user in lambdas_user:
                for lambda_item in lambdas_item:
                    error, w, z = matrix_factorization_SGD(train, test, g, k, num_epochs,lambda_item,lambda_user)
                    error_min = min(error[1:]) #because error[0]=0
                    errors[(g, k, error.index(error_min), lambda_user, lambda_item)] = error_min
    (gamma_final, k_final, num_epochs_final, lambda_user, lambda_item) = min(errors, key=errors.get)  #to get the best combination
    return gamma_final, k_final, num_epochs_final, lambda_user, lambda_item

# %%
def train_sgd_grid_search(ratings,gammas, Ks, num_epochs, lambdas_user, lambdas_item):
    '''This method does the grid search on the parameters given and then generates a submission for the best combination,
    using all the methods described before
    '''
    import time
    start_time = time.time()
    

    # do statistics.
    num_items_per_user = np.array((ratings != 0).sum(axis=0)).flatten()
    num_users_per_item = np.array((ratings != 0).sum(axis=1).T).flatten()

    valid_ratings, train, test = split_data(
        ratings, num_items_per_user, num_users_per_item, min_num_ratings=0, p_test=0.1)
    print("--- %s seconds ---" % (time.time() - start_time))

    # Grid search
    gamma_final, k_final, num_epochs_final, lambda_user, lambda_item = hyper_par(train, test, gammas, Ks, lambdas_user,lambdas_item,num_epochs)
    print(gamma_final)
    print(k_final)
    print(num_epochs_final)
    print(lambda_item)
    print(lambda_user)
    errors, item_features,user_features = matrix_factorization_SGD(train, test, gamma=gamma_final, num_features=k_final,
                                              num_epochs=num_epochs_final, lambda_item=lambda_item,
                                              lambda_user=lambda_user)
    print("--- %s seconds ---" % (time.time() - start_time))

# %%
gammas=[0.001,0.005,0.009,0.05]
Ks=[5,15,25,30,35,40]
num_epochs=2
lambdas_user=[0.01,0.02,0.015,0.005]
lambdas_item=[0.015,0.24,0.1,0.3,0.4]

train_sgd_grid_search(ratings,gammas, Ks, num_epochs, lambdas_user, lambdas_item)
# Out:
# the shape of original ratings. (# of row, # of col): (10000, 1000)
# the shape of valid ratings. (# of row, # of col): (10000, 1000)
# Total number of nonzero elements in origial data:1176952
# Total number of nonzero elements in train data:1065324
# Total number of nonzero elements in test data:111628
# --- 89.67246150970459 seconds ---
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0337956959632955.
# RMSE on test data: 1.0437305902135077.
# iter: 1, RMSE on training set: 1.0211454727504135.
# RMSE on test data: 1.0320494011588743.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0364825180948865.
# RMSE on test data: 1.046409051437782.
# iter: 1, RMSE on training set: 1.0268404643469666.
# RMSE on test data: 1.0377612340831752.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0345749904315813.
# RMSE on test data: 1.0445096191489966.
# iter: 1, RMSE on training set: 1.022656783200728.
# RMSE on test data: 1.0335743055797302.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.037532690987048.
# RMSE on test data: 1.0474529025241788.
# iter: 1, RMSE on training set: 1.029245745214044.
# RMSE on test data: 1.0401611235412334.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0395858592681024.
# RMSE on test data: 1.0494918320949775.
# iter: 1, RMSE on training set: 1.0340232086257837.
# RMSE on test data: 1.0449213073496508.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0330643546580556.
# RMSE on test data: 1.0430089299439922.
# iter: 1, RMSE on training set: 1.020286027135101.
# RMSE on test data: 1.0311929232120103.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.035800605680552.
# RMSE on test data: 1.045735127138423.
# iter: 1, RMSE on training set: 1.0260804227248712.
# RMSE on test data: 1.0370013990432574.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0338617124203673.
# RMSE on test data: 1.0438054103603995.
# iter: 1, RMSE on training set: 1.0218318549929002.
# RMSE on test data: 1.0327514203340853.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.036864814297624.
# RMSE on test data: 1.0467925238809328.
# iter: 1, RMSE on training set: 1.0285163448060268.
# RMSE on test data: 1.0394310321723097.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0389421351484256.
# RMSE on test data: 1.0488547553910268.
# iter: 1, RMSE on training set: 1.0333483324636394.
# RMSE on test data: 1.0442441096261879.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0334264037274883.
# RMSE on test data: 1.0433661456802672.
# iter: 1, RMSE on training set: 1.0207090903401241.
# RMSE on test data: 1.0316144772550304.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.036138008063539.
# RMSE on test data: 1.0460685435554886.
# iter: 1, RMSE on training set: 1.0264542262902383.
# RMSE on test data: 1.0373750749194819.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0342147546020664.
# RMSE on test data: 1.044153925502262.
# iter: 1, RMSE on training set: 1.0222378143934299.
# RMSE on test data: 1.0331563336025016.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0371952180467836.
# RMSE on test data: 1.047119186877208.
# iter: 1, RMSE on training set: 1.0288749620533506.
# RMSE on test data: 1.0397899703108104.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0392604956620581.
# RMSE on test data: 1.0491698007063794.
# iter: 1, RMSE on training set: 1.0336799244707284.
# RMSE on test data: 1.0445768371465447.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0341723447556868.
# RMSE on test data: 1.044102378889322.
# iter: 1, RMSE on training set: 1.021595585769855.
# RMSE on test data: 1.0324981164836582.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0368342451218822.
# RMSE on test data: 1.0467567620056772.
# iter: 1, RMSE on training set: 1.0272395158785488.
# RMSE on test data: 1.0381602654257225.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0349425317898602.
# RMSE on test data: 1.0448726051056012.
# iter: 1, RMSE on training set: 1.0230891611458948.
# RMSE on test data: 1.034005746053156.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0378773413631095.
# RMSE on test data: 1.0477937809180664.
# iter: 1, RMSE on training set: 1.0296290638540027.
# RMSE on test data: 1.0405448712795284.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0399183323531027.
# RMSE on test data: 1.049820957759724.
# iter: 1, RMSE on training set: 1.0343785381745976.
# RMSE on test data: 1.0452778832418086.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0960067682506165.
# RMSE on test data: 1.102192082595489.
# iter: 1, RMSE on training set: 1.0610459271899793.
# RMSE on test data: 1.0702351582946206.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.096750864176246.
# RMSE on test data: 1.1029951918724967.
# iter: 1, RMSE on training set: 1.0640185392782382.
# RMSE on test data: 1.073191570475411.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.096093971185955.
# RMSE on test data: 1.1023021789896115.
# iter: 1, RMSE on training set: 1.0616594223342894.
# RMSE on test data: 1.0708419719398166.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.097224726637888.
# RMSE on test data: 1.1034838814510268.
# iter: 1, RMSE on training set: 1.065522630573049.
# RMSE on test data: 1.0746919539534459.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.098266272950368.
# RMSE on test data: 1.1045492071634415.
# iter: 1, RMSE on training set: 1.0686565298059791.
# RMSE on test data: 1.0778199269142992.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0941814207475853.
# RMSE on test data: 1.100380961184412.
# iter: 1, RMSE on training set: 1.0590382678583998.
# RMSE on test data: 1.0682066463488948.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0950183654383077.
# RMSE on test data: 1.1012752335628462.
# iter: 1, RMSE on training set: 1.0622378779027917.
# RMSE on test data: 1.0713860246524194.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0943026123853634.
# RMSE on test data: 1.100524449178427.
# iter: 1, RMSE on training set: 1.0597308661331912.
# RMSE on test data: 1.0688912108990283.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0955185090045176.
# RMSE on test data: 1.1017896989281297.
# iter: 1, RMSE on training set: 1.0638115501796188.
# RMSE on test data: 1.0729546827336787.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.096605204708468.
# RMSE on test data: 1.1028992819621513.
# iter: 1, RMSE on training set: 1.0670689578390316.
# RMSE on test data: 1.0762037964777071.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.095087161124529.
# RMSE on test data: 1.101279449797444.
# iter: 1, RMSE on training set: 1.0600292241932026.
# RMSE on test data: 1.0692074495287998.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.095877904579934.
# RMSE on test data: 1.1021283652652518.
# iter: 1, RMSE on training set: 1.0631164230389223.
# RMSE on test data: 1.072276430566706.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0951914411538324.
# RMSE on test data: 1.1014063253248008.
# iter: 1, RMSE on training set: 1.0606826588958647.
# RMSE on test data: 1.0698535259652133.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.096364969285935.
# RMSE on test data: 1.102630004787681.
# iter: 1, RMSE on training set: 1.0646556263727822.
# RMSE on test data: 1.0738112722166788.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0974291950639317.
# RMSE on test data: 1.1037175644880806.
# iter: 1, RMSE on training set: 1.067851842397484.
# RMSE on test data: 1.0770003768599952.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0969404531233766.
# RMSE on test data: 1.1031190821652812.
# iter: 1, RMSE on training set: 1.06208909890132.
# RMSE on test data: 1.0712905626505806.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0976374477928417.
# RMSE on test data: 1.1038759284188793.
# iter: 1, RMSE on training set: 1.0649448987291572.
# RMSE on test data: 1.0741321837965288.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0970104106744214.
# RMSE on test data: 1.1032122299112472.
# iter: 1, RMSE on training set: 1.062661859837904.
# RMSE on test data: 1.0718573199643668.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0980979826391226.
# RMSE on test data: 1.1043515419310759.
# iter: 1, RMSE on training set: 1.066413221252077.
# RMSE on test data: 1.0755974534978403.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0991166366296445.
# RMSE on test data: 1.1053944196243815.
# iter: 1, RMSE on training set: 1.0694836554723242.
# RMSE on test data: 1.0786631487084122.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1368143636394374.
# RMSE on test data: 1.1438198472878358.
# iter: 1, RMSE on training set: 1.0854234719280047.
# RMSE on test data: 1.0962122887792385.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1364797071636974.
# RMSE on test data: 1.1434842905658766.
# iter: 1, RMSE on training set: 1.0866970221253407.
# RMSE on test data: 1.0974000187066877.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1365181599392495.
# RMSE on test data: 1.1435234579563123.
# iter: 1, RMSE on training set: 1.0854669559653476.
# RMSE on test data: 1.0962227423799824.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1366320610890492.
# RMSE on test data: 1.1436361271678381.
# iter: 1, RMSE on training set: 1.0876507090483156.
# RMSE on test data: 1.0983315144658534.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1371076163146032.
# RMSE on test data: 1.1441104656030439.
# iter: 1, RMSE on training set: 1.089786945974584.
# RMSE on test data: 1.100431122674862.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1344019511439176.
# RMSE on test data: 1.141386438074857.
# iter: 1, RMSE on training set: 1.0827670718980773.
# RMSE on test data: 1.093463862192037.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1341872288297996.
# RMSE on test data: 1.1411703520452319.
# iter: 1, RMSE on training set: 1.084349241586925.
# RMSE on test data: 1.094959482657527.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1341498590984285.
# RMSE on test data: 1.1411340261566973.
# iter: 1, RMSE on training set: 1.0829192747177394.
# RMSE on test data: 1.093582949703353.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1343732426892206.
# RMSE on test data: 1.1413556675368839.
# iter: 1, RMSE on training set: 1.085395976613947.
# RMSE on test data: 1.0959835725365488.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1349063893191742.
# RMSE on test data: 1.1418872441773622.
# iter: 1, RMSE on training set: 1.0876963272940376.
# RMSE on test data: 1.0982463207513187.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1355996262523207.
# RMSE on test data: 1.1425943666047584.
# iter: 1, RMSE on training set: 1.08407891850414.
# RMSE on test data: 1.094820721129087.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1353252464300285.
# RMSE on test data: 1.1423188581738966.
# iter: 1, RMSE on training set: 1.08550816621433.
# RMSE on test data: 1.0961637984756434.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1353255940634455.
# RMSE on test data: 1.1423200829418465.
# iter: 1, RMSE on training set: 1.0841772662487104.
# RMSE on test data: 1.0948860013141242.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.135494514677607.
# RMSE on test data: 1.1424875194663193.
# iter: 1, RMSE on training set: 1.0865087752048204.
# RMSE on test data: 1.0971419932648125.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1359990078506497.
# RMSE on test data: 1.1429906207197966.
# iter: 1, RMSE on training set: 1.0887277570727711.
# RMSE on test data: 1.0993238661526439.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1380464159742185.
# RMSE on test data: 1.145063148542662.
# iter: 1, RMSE on training set: 1.086801653376941.
# RMSE on test data: 1.097639585272872.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1376508551324163.
# RMSE on test data: 1.144666908928511.
# iter: 1, RMSE on training set: 1.087916682783583.
# RMSE on test data: 1.0986691141980687.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1377278061278362.
# RMSE on test data: 1.14474441630131.
# iter: 1, RMSE on training set: 1.0867892463117943.
# RMSE on test data: 1.0975941737744266.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1377861237814286.
# RMSE on test data: 1.1448017480612362.
# iter: 1, RMSE on training set: 1.0888226398064833.
# RMSE on test data: 1.0995530946594427.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1382324528630445.
# RMSE on test data: 1.1452470324632846.
# iter: 1, RMSE on training set: 1.090874736662743.
# RMSE on test data: 1.1015690288713675.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1539504763117432.
# RMSE on test data: 1.1607402582515678.
# iter: 1, RMSE on training set: 1.095623845465133.
# RMSE on test data: 1.1068510663913567.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1531545265064351.
# RMSE on test data: 1.160081738379506.
# iter: 1, RMSE on training set: 1.096105831857494.
# RMSE on test data: 1.1073598125355044.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1534875343653248.
# RMSE on test data: 1.1603291523625383.
# iter: 1, RMSE on training set: 1.0953906494971177.
# RMSE on test data: 1.1066260225056803.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1531732657748317.
# RMSE on test data: 1.1601371078881997.
# iter: 1, RMSE on training set: 1.0968179347958822.
# RMSE on test data: 1.1080814494313473.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1534166135156787.
# RMSE on test data: 1.1604412548760223.
# iter: 1, RMSE on training set: 1.098525995832798.
# RMSE on test data: 1.1098069445207943.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1513054694719573.
# RMSE on test data: 1.158056664471052.
# iter: 1, RMSE on training set: 1.09270681542203.
# RMSE on test data: 1.1037914318337105.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1506415067516824.
# RMSE on test data: 1.157528978964342.
# iter: 1, RMSE on training set: 1.0935317052764664.
# RMSE on test data: 1.1046421837457814.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1508911710366256.
# RMSE on test data: 1.157693801563754.
# iter: 1, RMSE on training set: 1.0925949973866849.
# RMSE on test data: 1.1036876314716129.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.150697151378684.
# RMSE on test data: 1.1576208968321127.
# iter: 1, RMSE on training set: 1.0943464203507058.
# RMSE on test data: 1.1054659139805318.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1510035296463361.
# RMSE on test data: 1.1579874341388152.
# iter: 1, RMSE on training set: 1.096234927803601.
# RMSE on test data: 1.1073707561669204.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1526187752401715.
# RMSE on test data: 1.1593888940379955.
# iter: 1, RMSE on training set: 1.0941473012936287.
# RMSE on test data: 1.1053018075008405.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1518891663738808.
# RMSE on test data: 1.1587961438520593.
# iter: 1, RMSE on training set: 1.0948022631217011.
# RMSE on test data: 1.1059831104682567.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1521802851864975.
# RMSE on test data: 1.1590020416870663.
# iter: 1, RMSE on training set: 1.093975352509134.
# RMSE on test data: 1.1051379549588827.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1519264525392499.
# RMSE on test data: 1.1588698831414666.
# iter: 1, RMSE on training set: 1.0955661030817079.
# RMSE on test data: 1.1067562330563951.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1522014740387563.
# RMSE on test data: 1.1592053860994045.
# iter: 1, RMSE on training set: 1.0973651278057241.
# RMSE on test data: 1.1085721555014836.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.155300846913443.
# RMSE on test data: 1.162111051721714.
# iter: 1, RMSE on training set: 1.0971375010593498.
# RMSE on test data: 1.1084403805531649.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1544378522887662.
# RMSE on test data: 1.1613860477757492.
# iter: 1, RMSE on training set: 1.097443416520415.
# RMSE on test data: 1.1087734110348324.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1548131893231903.
# RMSE on test data: 1.1616754246163843.
# iter: 1, RMSE on training set: 1.0968419221587113.
# RMSE on test data: 1.1081529858403916.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1544378538607525.
# RMSE on test data: 1.161422853854057.
# iter: 1, RMSE on training set: 1.0981029092145655.
# RMSE on test data: 1.1094426720049197.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1546492069620813.
# RMSE on test data: 1.1616953192169124.
# iter: 1, RMSE on training set: 1.0997185079040008.
# RMSE on test data: 1.1110762128869465.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1716251263251105.
# RMSE on test data: 1.1791949498671186.
# iter: 1, RMSE on training set: 1.1065456911168003.
# RMSE on test data: 1.1198422399203054.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.170582379179899.
# RMSE on test data: 1.1782343703970342.
# iter: 1, RMSE on training set: 1.1065156237387912.
# RMSE on test data: 1.1197447208026532.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1710768999901535.
# RMSE on test data: 1.1786774975258563.
# iter: 1, RMSE on training set: 1.1061368428445761.
# RMSE on test data: 1.1194057781447484.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1705240881595287.
# RMSE on test data: 1.1781982638319564.
# iter: 1, RMSE on training set: 1.107066793501324.
# RMSE on test data: 1.120280598945931.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1706289430223273.
# RMSE on test data: 1.1783401557005093.
# iter: 1, RMSE on training set: 1.1084859923316976.
# RMSE on test data: 1.1216762079460942.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1687221357057447.
# RMSE on test data: 1.1762364647010772.
# iter: 1, RMSE on training set: 1.1033234812507822.
# RMSE on test data: 1.1164277273987955.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.167824769972401.
# RMSE on test data: 1.175419087116956.
# iter: 1, RMSE on training set: 1.1036741135584.
# RMSE on test data: 1.1167077407872386.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1682276545539274.
# RMSE on test data: 1.1757719537976299.
# iter: 1, RMSE on training set: 1.1030503365756263.
# RMSE on test data: 1.1161259007242106.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1678068984819934.
# RMSE on test data: 1.1754227912023487.
# iter: 1, RMSE on training set: 1.1043379179689183.
# RMSE on test data: 1.1173552363952133.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1679805906786749.
# RMSE on test data: 1.1756324807418954.
# iter: 1, RMSE on training set: 1.1059542333721881.
# RMSE on test data: 1.1189461257315374.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1701637132260643.
# RMSE on test data: 1.1777053627213556.
# iter: 1, RMSE on training set: 1.1049145359119552.
# RMSE on test data: 1.1181132970041696.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1691940448081173.
# RMSE on test data: 1.1768167731703263.
# iter: 1, RMSE on training set: 1.1050764795980201.
# RMSE on test data: 1.1182062149463337.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.169642505321796.
# RMSE on test data: 1.1772145272604588.
# iter: 1, RMSE on training set: 1.1045741526148523.
# RMSE on test data: 1.1177447692110927.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1691560681135231.
# RMSE on test data: 1.1768006767961492.
# iter: 1, RMSE on training set: 1.1056844303151596.
# RMSE on test data: 1.1187983684599618.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1692955169532064.
# RMSE on test data: 1.1769766433569928.
# iter: 1, RMSE on training set: 1.1072029792225349.
# RMSE on test data: 1.1202924147273627.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.173106670809681.
# RMSE on test data: 1.180705546176536.
# iter: 1, RMSE on training set: 1.1082181418373631.
# RMSE on test data: 1.1216158895091453.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.171990059214026.
# RMSE on test data: 1.1796721889014792.
# iter: 1, RMSE on training set: 1.1079926921945022.
# RMSE on test data: 1.1213245402369714.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1725311306509296.
# RMSE on test data: 1.1801611808247092.
# iter: 1, RMSE on training set: 1.1077395823663712.
# RMSE on test data: 1.1211102400695785.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1719112422441416.
# RMSE on test data: 1.1796158598397903.
# iter: 1, RMSE on training set: 1.1084861426625507.
# RMSE on test data: 1.1218031978219192.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1719811484071259.
# RMSE on test data: 1.1797233210751332.
# iter: 1, RMSE on training set: 1.1098043908818649.
# RMSE on test data: 1.1230987569320678.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1848873998071812.
# RMSE on test data: 1.1944156974484554.
# iter: 1, RMSE on training set: 1.1148239907930761.
# RMSE on test data: 1.1292652218042718.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1834475433318798.
# RMSE on test data: 1.1930331496744122.
# iter: 1, RMSE on training set: 1.1140450743178207.
# RMSE on test data: 1.128395394479618.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1841930754385923.
# RMSE on test data: 1.1937427235021671.
# iter: 1, RMSE on training set: 1.1141458270312226.
# RMSE on test data: 1.128550534540934.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1832777787119155.
# RMSE on test data: 1.1928789871018792.
# iter: 1, RMSE on training set: 1.114378148157058.
# RMSE on test data: 1.1287069608287266.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1831917405844883.
# RMSE on test data: 1.1928190578566242.
# iter: 1, RMSE on training set: 1.1154186656224196.
# RMSE on test data: 1.1297135316904643.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1818105394502356.
# RMSE on test data: 1.191247151779506.
# iter: 1, RMSE on training set: 1.1113562797491503.
# RMSE on test data: 1.1255446364832629.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1805257317120867.
# RMSE on test data: 1.190019001546695.
# iter: 1, RMSE on training set: 1.1109857225245519.
# RMSE on test data: 1.1250841658258515.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1811736348248387.
# RMSE on test data: 1.190631385478416.
# iter: 1, RMSE on training set: 1.110824171760964.
# RMSE on test data: 1.1249765543999617.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1803989334252127.
# RMSE on test data: 1.1899075840380846.
# iter: 1, RMSE on training set: 1.1114389573764274.
# RMSE on test data: 1.1255159215389772.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1803859501810692.
# RMSE on test data: 1.1899202983791664.
# iter: 1, RMSE on training set: 1.1126892931887296.
# RMSE on test data: 1.1267321554118193.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1833384963421392.
# RMSE on test data: 1.1928204484043692.
# iter: 1, RMSE on training set: 1.1130682758677504.
# RMSE on test data: 1.1273811576634152.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.181976581317149.
# RMSE on test data: 1.1915155214247544.
# iter: 1, RMSE on training set: 1.1124953007325424.
# RMSE on test data: 1.1267178011033345.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1826730388101907.
# RMSE on test data: 1.192176237095668.
# iter: 1, RMSE on training set: 1.1124637938933535.
# RMSE on test data: 1.1267404384518254.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.181828411969023.
# RMSE on test data: 1.191382844826987.
# iter: 1, RMSE on training set: 1.1128889418457946.
# RMSE on test data: 1.1270899570937882.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1817790889885553.
# RMSE on test data: 1.1913594273191566.
# iter: 1, RMSE on training set: 1.114035195953693.
# RMSE on test data: 1.128202200482423.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1864575675403641.
# RMSE on test data: 1.1960332386115275.
# iter: 1, RMSE on training set: 1.1166247804246414.
# RMSE on test data: 1.1311983223789985.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1849389253862823.
# RMSE on test data: 1.1945722156909084.
# iter: 1, RMSE on training set: 1.115636350513744.
# RMSE on test data: 1.1301183885041144.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1857340585363207.
# RMSE on test data: 1.1953311804424438.
# iter: 1, RMSE on training set: 1.1158716069062042.
# RMSE on test data: 1.1304083152038802.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1847473386910776.
# RMSE on test data: 1.1943963375959379.
# iter: 1, RMSE on training set: 1.1159078729485927.
# RMSE on test data: 1.1303683639843358.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.1846242057630398.
# RMSE on test data: 1.1942995123613376.
# iter: 1, RMSE on training set: 1.1168409830829968.
# RMSE on test data: 1.1312675632474927.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0183742404028802.
# RMSE on test data: 1.0311628702459845.
# iter: 1, RMSE on training set: 1.0090109569319758.
# RMSE on test data: 1.0228473912184108.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0336798301920704.
# RMSE on test data: 1.0463850308113802.
# iter: 1, RMSE on training set: 1.0332399520912319.
# RMSE on test data: 1.0468880792615052.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.021508547742565.
# RMSE on test data: 1.0342852321620781.
# iter: 1, RMSE on training set: 1.0144693638337643.
# RMSE on test data: 1.0282147174795877.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.040930124474142.
# RMSE on test data: 1.053595348109283.
# iter: 1, RMSE on training set: 1.0425467264780184.
# RMSE on test data: 1.056194996529978.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0549311048795997.
# RMSE on test data: 1.0675281398041103.
# iter: 1, RMSE on training set: 1.0574949465243912.
# RMSE on test data: 1.0712035946297134.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0177147905905786.
# RMSE on test data: 1.0304529392857777.
# iter: 1, RMSE on training set: 1.0086326527191274.
# RMSE on test data: 1.0223327209887025.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0334196737467631.
# RMSE on test data: 1.0460666789878696.
# iter: 1, RMSE on training set: 1.0338935661647595.
# RMSE on test data: 1.0474135151986148.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0209590241369328.
# RMSE on test data: 1.033682899378905.
# iter: 1, RMSE on training set: 1.0143127356721695.
# RMSE on test data: 1.0279270330649248.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0408281787719669.
# RMSE on test data: 1.0534324392996146.
# iter: 1, RMSE on training set: 1.0436949444694197.
# RMSE on test data: 1.0572139255265864.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0551299398621756.
# RMSE on test data: 1.0676609377996735.
# iter: 1, RMSE on training set: 1.0596120165839866.
# RMSE on test data: 1.0731873359991153.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.018032461973482.
# RMSE on test data: 1.0307954289936863.
# iter: 1, RMSE on training set: 1.008811698877845.
# RMSE on test data: 1.0225785113790082.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0335439821245453.
# RMSE on test data: 1.0462195426285141.
# iter: 1, RMSE on training set: 1.033585415494885.
# RMSE on test data: 1.0471676223243305.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.021223562474912.
# RMSE on test data: 1.0339733783697589.
# iter: 1, RMSE on training set: 1.0143883220730239.
# RMSE on test data: 1.0280665991123592.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.040875716988594.
# RMSE on test data: 1.053509882715484.
# iter: 1, RMSE on training set: 1.0431507657639851.
# RMSE on test data: 1.0567324318518043.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0550313933148228.
# RMSE on test data: 1.0675947799839949.
# iter: 1, RMSE on training set: 1.0586026091190055.
# RMSE on test data: 1.0722424555637116.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0187421973080715.
# RMSE on test data: 1.0315574483274894.
# iter: 1, RMSE on training set: 1.0092333216323401.
# RMSE on test data: 1.0231426167672995.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.033828375081653.
# RMSE on test data: 1.0465644360081716.
# iter: 1, RMSE on training set: 1.0328536804994786.
# RMSE on test data: 1.0465720135556975.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.021815770320102.
# RMSE on test data: 1.0346203730618204.
# iter: 1, RMSE on training set: 1.0145568185263716.
# RMSE on test data: 1.0283728027948964.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0409922408520063.
# RMSE on test data: 1.0536898157487309.
# iter: 1, RMSE on training set: 1.0418775797517457.
# RMSE on test data: 1.055597055079638.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0548293482380502.
# RMSE on test data: 1.067461439353768.
# iter: 1, RMSE on training set: 1.0562819048337362.
# RMSE on test data: 1.0700643815615745.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0337617997374144.
# RMSE on test data: 1.0477405264999728.
# iter: 1, RMSE on training set: 1.0126558733589552.
# RMSE on test data: 1.0308443284563464.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0426706075402634.
# RMSE on test data: 1.056364379484269.
# iter: 1, RMSE on training set: 1.0283442452785523.
# RMSE on test data: 1.0453996833052817.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0350889634612739.
# RMSE on test data: 1.0489406451707513.
# iter: 1, RMSE on training set: 1.0162708216108733.
# RMSE on test data: 1.0339322735565368.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0475118193902533.
# RMSE on test data: 1.0611568726265819.
# iter: 1, RMSE on training set: 1.033806258520747.
# RMSE on test data: 1.0507136329445095.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.05709938120979.
# RMSE on test data: 1.0706868928238986.
# iter: 1, RMSE on training set: 1.0418154695944.
# RMSE on test data: 1.0586021591338406.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.03221735302446.
# RMSE on test data: 1.0459759350693703.
# iter: 1, RMSE on training set: 1.011855394020646.
# RMSE on test data: 1.029619209790173.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0423390025314512.
# RMSE on test data: 1.0558045157725746.
# iter: 1, RMSE on training set: 1.0308264139879815.
# RMSE on test data: 1.0473897019381413.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0338996301335872.
# RMSE on test data: 1.0475301897355143.
# iter: 1, RMSE on training set: 1.0163776585499096.
# RMSE on test data: 1.0335913234171044.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0476259413150595.
# RMSE on test data: 1.061038281098425.
# iter: 1, RMSE on training set: 1.0374201033012043.
# RMSE on test data: 1.0538188722382242.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.058028433464628.
# RMSE on test data: 1.071374723374334.
# iter: 1, RMSE on training set: 1.0472172260139199.
# RMSE on test data: 1.0634746812520643.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0329663187592306.
# RMSE on test data: 1.0468313779005627.
# iter: 1, RMSE on training set: 1.0122386739774354.
# RMSE on test data: 1.0302067189558046.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.042495598453373.
# RMSE on test data: 1.056071448978417.
# iter: 1, RMSE on training set: 1.0296248837394886.
# RMSE on test data: 1.0464236443253558.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0344754201025694.
# RMSE on test data: 1.0482128818410774.
# iter: 1, RMSE on training set: 1.016328144651073.
# RMSE on test data: 1.0337565296240696.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0475644177966246.
# RMSE on test data: 1.0610892613241445.
# iter: 1, RMSE on training set: 1.035662014028842.
# RMSE on test data: 1.0523041226032923.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.05756771294915.
# RMSE on test data: 1.0710306617619136.
# iter: 1, RMSE on training set: 1.0445691932196417.
# RMSE on test data: 1.0610800314231723.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.034607306841571.
# RMSE on test data: 1.0487076641822388.
# iter: 1, RMSE on training set: 1.0131102190705847.
# RMSE on test data: 1.031538146383405.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0428670859719809.
# RMSE on test data: 1.0566871453140732.
# iter: 1, RMSE on training set: 1.0269930504307665.
# RMSE on test data: 1.0443293278792092.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0357435625331604.
# RMSE on test data: 1.0497175619069161.
# iter: 1, RMSE on training set: 1.0162084728457226.
# RMSE on test data: 1.034124346207475.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0474711473571479.
# RMSE on test data: 1.0612448960462764.
# iter: 1, RMSE on training set: 1.0318663073502765.
# RMSE on test data: 1.0490637417879678.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.056626434674582.
# RMSE on test data: 1.0703471864462017.
# iter: 1, RMSE on training set: 1.038979239324979.
# RMSE on test data: 1.0560669384446568.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.041925230631085.
# RMSE on test data: 1.0607238320448589.
# iter: 1, RMSE on training set: 1.0143939137323843.
# RMSE on test data: 1.0377538056774962.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0469222496973147.
# RMSE on test data: 1.0649572437698358.
# iter: 1, RMSE on training set: 1.0242351239178984.
# RMSE on test data: 1.046019547601613.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.042181060902858.
# RMSE on test data: 1.0606866437015086.
# iter: 1, RMSE on training set: 1.0163426912873115.
# RMSE on test data: 1.0389999930194502.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0502511298612234.
# RMSE on test data: 1.0680963452894305.
# iter: 1, RMSE on training set: 1.0277907745212689.
# RMSE on test data: 1.0493029242314513.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0570701030889806.
# RMSE on test data: 1.0746225751848628.
# iter: 1, RMSE on training set: 1.0329219240838852.
# RMSE on test data: 1.0540838236234817.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0398232324591044.
# RMSE on test data: 1.0581794249173553.
# iter: 1, RMSE on training set: 1.0132033843590025.
# RMSE on test data: 1.0357471217895218.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0464928812213488.
# RMSE on test data: 1.0640821439026655.
# iter: 1, RMSE on training set: 1.0273122064625688.
# RMSE on test data: 1.0482301490997714.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0405899834746228.
# RMSE on test data: 1.0586539699515942.
# iter: 1, RMSE on training set: 1.0164619582610697.
# RMSE on test data: 1.0382831684496898.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0504081009010984.
# RMSE on test data: 1.067804581213483.
# iter: 1, RMSE on training set: 1.0321216506100106.
# RMSE on test data: 1.0527606455209413.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0582799631512587.
# RMSE on test data: 1.0753780117679324.
# iter: 1, RMSE on training set: 1.039057115306246.
# RMSE on test data: 1.0593448652493995.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.040840438225045.
# RMSE on test data: 1.0594116115743097.
# iter: 1, RMSE on training set: 1.0137685520941064.
# RMSE on test data: 1.0367049102007182.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0466872286960083.
# RMSE on test data: 1.064492961791647.
# iter: 1, RMSE on training set: 1.0257795805365766.
# RMSE on test data: 1.0471136141060906.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.04135628203581.
# RMSE on test data: 1.05963476670466.
# iter: 1, RMSE on training set: 1.0163900988481787.
# RMSE on test data: 1.0386129517068714.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0503133631314594.
# RMSE on test data: 1.0679277877684252.
# iter: 1, RMSE on training set: 1.029961376054493.
# RMSE on test data: 1.051019776555307.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0576655864113964.
# RMSE on test data: 1.074984396285032.
# iter: 1, RMSE on training set: 1.0359832861326075.
# RMSE on test data: 1.0566911500589444.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0430837879985273.
# RMSE on test data: 1.0621233892931956.
# iter: 1, RMSE on training set: 1.0150895426593693.
# RMSE on test data: 1.0389085286035606.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.047205404731654.
# RMSE on test data: 1.0654835678014591.
# iter: 1, RMSE on training set: 1.0227115588199427.
# RMSE on test data: 1.0449849311589479.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.04307078291017.
# RMSE on test data: 1.0618171979197142.
# iter: 1, RMSE on training set: 1.0163357595854212.
# RMSE on test data: 1.0394649337908395.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0502294445339322.
# RMSE on test data: 1.0683193988563553.
# iter: 1, RMSE on training set: 1.0256499193484643.
# RMSE on test data: 1.0476542592746203.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0565026800088972.
# RMSE on test data: 1.0743027831053658.
# iter: 1, RMSE on training set: 1.029923125535562.
# RMSE on test data: 1.0515768737396491.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0477908000100422.
# RMSE on test data: 1.068369083666664.
# iter: 1, RMSE on training set: 1.0162259759542318.
# RMSE on test data: 1.0426471335672665.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0501447465228693.
# RMSE on test data: 1.0699284791365575.
# iter: 1, RMSE on training set: 1.0236101988499504.
# RMSE on test data: 1.0478774617561093.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0470745862695081.
# RMSE on test data: 1.0673273526014193.
# iter: 1, RMSE on training set: 1.0174465026836474.
# RMSE on test data: 1.0429412429235183.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0527418792967658.
# RMSE on test data: 1.0723512085019316.
# iter: 1, RMSE on training set: 1.0264201752349251.
# RMSE on test data: 1.0502752030732687.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.058336745196448.
# RMSE on test data: 1.077690939835796.
# iter: 1, RMSE on training set: 1.0304595279715225.
# RMSE on test data: 1.053754311342867.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0453760333989546.
# RMSE on test data: 1.0653539656458395.
# iter: 1, RMSE on training set: 1.014897280893124.
# RMSE on test data: 1.0402906617337377.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0495446117006304.
# RMSE on test data: 1.0687273759708529.
# iter: 1, RMSE on training set: 1.0268210379972833.
# RMSE on test data: 1.0500004138524526.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0452159626752702.
# RMSE on test data: 1.0648704239693274.
# iter: 1, RMSE on training set: 1.0175628269058852.
# RMSE on test data: 1.0420072870191028.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0527749681976437.
# RMSE on test data: 1.0717808027707982.
# iter: 1, RMSE on training set: 1.0308939662681995.
# RMSE on test data: 1.0536522755288296.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0595036468710455.
# RMSE on test data: 1.0782493346886446.
# iter: 1, RMSE on training set: 1.0367011011196912.
# RMSE on test data: 1.058896738593368.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0465420550047146.
# RMSE on test data: 1.066811673601754.
# iter: 1, RMSE on training set: 1.0155231496511028.
# RMSE on test data: 1.0414113237982492.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0498155038975672.
# RMSE on test data: 1.069290238627733.
# iter: 1, RMSE on training set: 1.0252020312747248.
# RMSE on test data: 1.048904744498923.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0461081674333146.
# RMSE on test data: 1.0660532688965045.
# iter: 1, RMSE on training set: 1.017481218846189.
# RMSE on test data: 1.0424308809252592.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0527327839559917.
# RMSE on test data: 1.0720318656942527.
# iter: 1, RMSE on training set: 1.0286395553637449.
# RMSE on test data: 1.0519255927148081.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0589003276607856.
# RMSE on test data: 1.0779418107447565.
# iter: 1, RMSE on training set: 1.0335480642583277.
# RMSE on test data: 1.056272811405109.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0491304465661138.
# RMSE on test data: 1.0700357810077685.
# iter: 1, RMSE on training set: 1.017020762396425.
# RMSE on test data: 1.0440180260217835.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.050542469639248.
# RMSE on test data: 1.0706535722181791.
# iter: 1, RMSE on training set: 1.022087641100012.
# RMSE on test data: 1.0469650970913107.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0481238701637703.
# RMSE on test data: 1.068702720808583.
# iter: 1, RMSE on training set: 1.017481805939938.
# RMSE on test data: 1.043566312429433.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0528132108243995.
# RMSE on test data: 1.0727511036589288.
# iter: 1, RMSE on training set: 1.024285219103292.
# RMSE on test data: 1.0487548122638817.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0578254002560359.
# RMSE on test data: 1.0775104853023951.
# iter: 1, RMSE on training set: 1.0274938457335037.
# RMSE on test data: 1.0514038148335452.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.053683778741221.
# RMSE on test data: 1.0773648670435574.
# iter: 1, RMSE on training set: 1.0180577056573072.
# RMSE on test data: 1.047760141518679.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0548962338348522.
# RMSE on test data: 1.0775015855606886.
# iter: 1, RMSE on training set: 1.024388716369571.
# RMSE on test data: 1.051749180878938.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.052632920825471.
# RMSE on test data: 1.075866129286688.
# iter: 1, RMSE on training set: 1.0189663784844576.
# RMSE on test data: 1.047674941528461.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0570811502438069.
# RMSE on test data: 1.0794556227955865.
# iter: 1, RMSE on training set: 1.0268581259326472.
# RMSE on test data: 1.053747193984156.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.061938168172354.
# RMSE on test data: 1.0839733477501348.
# iter: 1, RMSE on training set: 1.0303490410515916.
# RMSE on test data: 1.0565692360020387.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0509031980606218.
# RMSE on test data: 1.0738477138020117.
# iter: 1, RMSE on training set: 1.0165100556031355.
# RMSE on test data: 1.0449065177939154.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0540804688487435.
# RMSE on test data: 1.0759361183455556.
# iter: 1, RMSE on training set: 1.0276002672718842.
# RMSE on test data: 1.0535919259374682.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0504674998595382.
# RMSE on test data: 1.0729600789155034.
# iter: 1, RMSE on training set: 1.0189592219469776.
# RMSE on test data: 1.0463300203925994.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0569356758890478.
# RMSE on test data: 1.0785563486794205.
# iter: 1, RMSE on training set: 1.0313664730139958.
# RMSE on test data: 1.0568848921012723.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0629857413997155.
# RMSE on test data: 1.0842607328093963.
# iter: 1, RMSE on training set: 1.0366596911613668.
# RMSE on test data: 1.061520439032321.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0522447594372761.
# RMSE on test data: 1.0755475405320687.
# iter: 1, RMSE on training set: 1.0172347760693965.
# RMSE on test data: 1.046261568505064.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0544510681558676.
# RMSE on test data: 1.0766713832626507.
# iter: 1, RMSE on training set: 1.0259650322129814.
# RMSE on test data: 1.0526166317664831.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0515056124302307.
# RMSE on test data: 1.0743583912436838.
# iter: 1, RMSE on training set: 1.0189271223295107.
# RMSE on test data: 1.0469430606833539.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0569742973918637.
# RMSE on test data: 1.078961680824736.
# ...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: nan.
# RMSE on test data: nan.
# iter: 1, RMSE on training set: nan.
# RMSE on test data: nan.
# 0.005
# 5
# 2
# 0.015
# 0.02
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0177147905905786.
# RMSE on test data: 1.0304529392857777.
# iter: 1, RMSE on training set: 1.0086326527191274.
# RMSE on test data: 1.0223327209887025.
# --- 57692.45667862892 seconds ---

# %%
import time
start_time=time.time()

num_items_per_user = np.array((ratings != 0).sum(axis=0)).flatten()
num_users_per_item = np.array((ratings != 0).sum(axis=1).T).flatten()

valid_ratings, train, test = split_data(
        ratings, num_items_per_user, num_users_per_item, min_num_ratings=0, p_test=0.1)
print("--- %s seconds ---" % (time.time() - start_time))
errors, item_features,user_features = matrix_factorization_SGD(train, test, gamma=0.005, num_features=5,
                                              num_epochs=100, lambda_item=0.015,
                                              lambda_user=0.02)
# Out:
# the shape of original ratings. (# of row, # of col): (10000, 1000)
# the shape of valid ratings. (# of row, # of col): (10000, 1000)
# Total number of nonzero elements in origial data:1176952
# Total number of nonzero elements in train data:1065324
# Total number of nonzero elements in test data:111628
# --- 127.09667897224426 seconds ---
# learn the matrix factorization using SGD...
# iter: 0, RMSE on training set: 1.0177147905905786.
# RMSE on test data: 1.0304529392857777.
# iter: 1, RMSE on training set: 1.0086326527191274.
# RMSE on test data: 1.0223327209887025.
# iter: 2, RMSE on training set: 1.0036789192108178.
# RMSE on test data: 1.0179152465096732.
# iter: 3, RMSE on training set: 0.999991395992896.
# RMSE on test data: 1.014302540788575.
# iter: 4, RMSE on training set: 0.9981115929210609.
# RMSE on test data: 1.0129684490644058.
# iter: 5, RMSE on training set: 0.995478947463597.
# RMSE on test data: 1.0105147403761665.
# iter: 6, RMSE on training set: 0.9940271896241553.
# RMSE on test data: 1.0094769633381706.
# iter: 7, RMSE on training set: 0.9932122482072387.
# RMSE on test data: 1.008505289939075.
# iter: 8, RMSE on training set: 0.9918193600280731.
# RMSE on test data: 1.0071211690640856.
# iter: 9, RMSE on training set: 0.9909027521698834.
# RMSE on test data: 1.0058672194333271.
# iter: 10, RMSE on training set: 0.9906926413468188.
# RMSE on test data: 1.0059812709695921.
# iter: 11, RMSE on training set: 0.9899675277647796.
# RMSE on test data: 1.0051982114295388.
# iter: 12, RMSE on training set: 0.9896310879843844.
# RMSE on test data: 1.0051730195225699.
# iter: 13, RMSE on training set: 0.9891383122764804.
# RMSE on test data: 1.0045492191581094.
# iter: 14, RMSE on training set: 0.9889673716343034.
# RMSE on test data: 1.004472495824143.
# iter: 15, RMSE on training set: 0.9887719351077553.
# RMSE on test data: 1.0042882761704084.
# iter: 16, RMSE on training set: 0.988595000522494.
# RMSE on test data: 1.0040560047616969.
# iter: 17, RMSE on training set: 0.9883832114952523.
# RMSE on test data: 1.0039926366786749.
# iter: 18, RMSE on training set: 0.9882764378960506.
# RMSE on test data: 1.003950479266807.
# iter: 19, RMSE on training set: 0.98816974046358.
# RMSE on test data: 1.0038017721738584.
# iter: 20, RMSE on training set: 0.9880956106947768.
# RMSE on test data: 1.0036698027053073.
# iter: 21, RMSE on training set: 0.988026539681991.
# RMSE on test data: 1.0037191071223786.
# iter: 22, RMSE on training set: 0.9879937996513126.
# RMSE on test data: 1.0036563997091679.
# iter: 23, RMSE on training set: 0.9879610628876425.
# RMSE on test data: 1.0036304780907366.
# iter: 24, RMSE on training set: 0.9879363662458572.
# RMSE on test data: 1.003579248117434.
# iter: 25, RMSE on training set: 0.9879173872708124.
# RMSE on test data: 1.0035234810675138.
# iter: 26, RMSE on training set: 0.9879030376048538.
# RMSE on test data: 1.003539879577844.
# iter: 27, RMSE on training set: 0.9878930187727233.
# RMSE on test data: 1.0035454306210156.
# iter: 28, RMSE on training set: 0.9878865274915619.
# RMSE on test data: 1.0035426927163498.
# iter: 29, RMSE on training set: 0.9878823879275471.
# RMSE on test data: 1.003528284894287.
# iter: 30, RMSE on training set: 0.9878777852805093.
# RMSE on test data: 1.0035213015651399.
# iter: 31, RMSE on training set: 0.9878738397239597.
# RMSE on test data: 1.0035267736209519.
# iter: 32, RMSE on training set: 0.9878710215072353.
# RMSE on test data: 1.0035288555505102.
# iter: 33, RMSE on training set: 0.9878688661289174.
# RMSE on test data: 1.003529173958752.
# iter: 34, RMSE on training set: 0.9878671432612935.
# RMSE on test data: 1.0035279097926006.
# iter: 35, RMSE on training set: 0.9878655626325329.
# RMSE on test data: 1.003527890283458.
# iter: 36, RMSE on training set: 0.9878642933911302.
# RMSE on test data: 1.0035278740581839.
# iter: 37, RMSE on training set: 0.9878633279830875.
# RMSE on test data: 1.003527874501168.
# iter: 38, RMSE on training set: 0.9878624620350133.
# RMSE on test data: 1.0035274811330241.
# iter: 39, RMSE on training set: 0.987861804653231.
# RMSE on test data: 1.0035273918174528.
# iter: 40, RMSE on training set: 0.9878612689892501.
# RMSE on test data: 1.0035271855463255.
# iter: 41, RMSE on training set: 0.9878607965639887.
# RMSE on test data: 1.003527084055187.
# iter: 42, RMSE on training set: 0.9878604058382549.
# RMSE on test data: 1.0035269369822317.
# iter: 43, RMSE on training set: 0.9878600777729193.
# RMSE on test data: 1.003526803186527.
# iter: 44, RMSE on training set: 0.9878598096512784.
# RMSE on test data: 1.0035267233550103.
# iter: 45, RMSE on training set: 0.9878595828215186.
# RMSE on test data: 1.0035266661915059.
# iter: 46, RMSE on training set: 0.9878593973473838.
# RMSE on test data: 1.0035266196911103.
# iter: 47, RMSE on training set: 0.9878592421098112.
# RMSE on test data: 1.0035265949187064.
# iter: 48, RMSE on training set: 0.9878591139967632.
# RMSE on test data: 1.003526554745181.
# iter: 49, RMSE on training set: 0.9878590071386687.
# RMSE on test data: 1.0035265288687023.
# iter: 50, RMSE on training set: 0.9878589163283901.
# RMSE on test data: 1.0035265076851374.
# iter: 51, RMSE on training set: 0.9878588421155935.
# RMSE on test data: 1.0035264893746834.
# iter: 52, RMSE on training set: 0.9878587797306044.
# RMSE on test data: 1.0035264722337758.
# iter: 53, RMSE on training set: 0.9878587275695557.
# RMSE on test data: 1.0035264595613163.
# iter: 54, RMSE on training set: 0.9878586843408539.
# RMSE on test data: 1.003526448437376.
# iter: 55, RMSE on training set: 0.9878586482265583.
# RMSE on test data: 1.0035264389610437.
# iter: 56, RMSE on training set: 0.9878586181852991.
# RMSE on test data: 1.0035264316209698.
# iter: 57, RMSE on training set: 0.9878585931189434.
# RMSE on test data: 1.0035264248025089.
# iter: 58, RMSE on training set: 0.9878585722178737.
# RMSE on test data: 1.003526419151113.
# iter: 59, RMSE on training set: 0.9878585548023154.
# RMSE on test data: 1.00352641455206.
# iter: 60, RMSE on training set: 0.987858540296135.
# RMSE on test data: 1.0035264106943718.
# iter: 61, RMSE on training set: 0.9878585282115135.
# RMSE on test data: 1.0035264075103012.
# iter: 62, RMSE on training set: 0.9878585181404711.
# RMSE on test data: 1.0035264047775314.
# iter: 63, RMSE on training set: 0.9878585097368155.
# RMSE on test data: 1.0035264025195476.
# iter: 64, RMSE on training set: 0.9878585027361976.
# RMSE on test data: 1.0035264006339084.
# iter: 65, RMSE on training set: 0.9878584969046298.
# RMSE on test data: 1.0035263990492829.
# iter: 66, RMSE on training set: 0.9878584920471882.
# RMSE on test data: 1.0035263977281192.
# iter: 67, RMSE on training set: 0.9878584879985899.
# RMSE on test data: 1.0035263966537817.
# iter: 68, RMSE on training set: 0.9878584846252095.
# RMSE on test data: 1.0035263957530074.
# iter: 69, RMSE on training set: 0.987858481813813.
# RMSE on test data: 1.0035263950053077.
# iter: 70, RMSE on training set: 0.9878584794710134.
# RMSE on test data: 1.0035263943752564.
# iter: 71, RMSE on training set: 0.9878584775182725.
# RMSE on test data: 1.0035263938529733.
# iter: 72, RMSE on training set: 0.9878584758909924.
# RMSE on test data: 1.0035263934168615.
# iter: 73, RMSE on training set: 0.9878584745349293.
# RMSE on test data: 1.0035263930524612.
# iter: 74, RMSE on training set: 0.9878584734049676.
# RMSE on test data: 1.003526392749218.
# iter: 75, RMSE on training set: 0.987858472463263.
# RMSE on test data: 1.0035263924970832.
# iter: 76, RMSE on training set: 0.9878584716785467.
# RMSE on test data: 1.0035263922865258.
# iter: 77, RMSE on training set: 0.9878584710246273.
# RMSE on test data: 1.0035263921115039.
# iter: 78, RMSE on training set: 0.9878584704796464.
# RMSE on test data: 1.003526391965616.
# iter: 79, RMSE on training set: 0.9878584700255226.
# RMSE on test data: 1.003526391844015.
# iter: 80, RMSE on training set: 0.9878584696470708.
# RMSE on test data: 1.0035263917425714.
# iter: 81, RMSE on training set: 0.9878584693317349.
# RMSE on test data: 1.0035263916580974.
# iter: 82, RMSE on training set: 0.9878584690689209.
# RMSE on test data: 1.003526391587654.
# iter: 83, RMSE on training set: 0.9878584688499167.
# RMSE on test data: 1.0035263915289916.
# iter: 84, RMSE on training set: 0.9878584686673898.
# RMSE on test data: 1.003526391480117.
# iter: 85, RMSE on training set: 0.9878584685153322.
# RMSE on test data: 1.003526391439381.
# iter: 86, RMSE on training set: 0.9878584683885702.
# RMSE on test data: 1.003526391405422.
# iter: 87, RMSE on training set: 0.9878584682829592.
# RMSE on test data: 1.003526391377136.
# iter: 88, RMSE on training set: 0.9878584681949393.
# RMSE on test data: 1.003526391353541.
# iter: 89, RMSE on training set: 0.9878584681216473.
# RMSE on test data: 1.0035263913339096.
# iter: 90, RMSE on training set: 0.9878584680604869.
# RMSE on test data: 1.0035263913175365.
# iter: 91, RMSE on training set: 0.9878584680095447.
# RMSE on test data: 1.0035263913038885.
# iter: 92, RMSE on training set: 0.9878584679671046.
# RMSE on test data: 1.0035263912925312.
# iter: 93, RMSE on training set: 0.9878584679317653.
# RMSE on test data: 1.003526391283042.
# iter: 94, RMSE on training set: 0.987858467902265.
# RMSE on test data: 1.0035263912751486.
# iter: 95, RMSE on training set: 0.9878584678776997.
# RMSE on test data: 1.0035263912685646.
# iter: 96, RMSE on training set: 0.9878584678572417.
# RMSE on test data: 1.0035263912630825.
# iter: 97, RMSE on training set: 0.9878584678401541.
# RMSE on test data: 1.0035263912585206.
# iter: 98, RMSE on training set: 0.9878584678259702.
# RMSE on test data: 1.003526391254698.
# iter: 99, RMSE on training set: 0.9878584678141119.
# RMSE on test data: 1.003526391251529.

# %%
def prediction(test,item_features,user_features):
    nz_row, nz_col = test.T.shape
    A=item_features.T.dot(user_features)
    prediction=np.array([])
    for user in range(nz_row):
        if user%100==0:
            print(user)
        test_ratings = test[:, user]
        item=test_ratings.nonzero()
        prediction=np.append(prediction,A[item[0],user])
    return prediction
prediction_sgd=prediction(test_submission,item_features,user_features)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
from helpers import *
OUTPUT_PATH = 'SGD_best_combination2.csv' 

prediction_sgd=np.round(prediction_sgd.flatten())
a=np.where(prediction_sgd>5)[0]
prediction_sgd[a]=5

submission(path_test,prediction_sgd,OUTPUT_PATH)

# %% [markdown]
# ## ALS

# %%
def update_user_feature(
        train, item_features, lambda_user,
        nnz_items_per_user, nz_user_itemindices):
    """update user feature matrix."""
    """the best lambda is assumed to be nnz_items_per_user[user] * lambda_user"""
    num_user = nnz_items_per_user.shape[0]
    num_feature = item_features.shape[0]
    lambda_I = lambda_user * sp.eye(num_feature)
    updated_user_features = np.zeros((num_feature, num_user))

    for user, items in nz_user_itemindices:
        # extract the columns corresponding to the prediction for given item
        M = item_features[:, items]
        
        # update column row of user features
        V = M @ train[items, user]
        A = M @ M.T + nnz_items_per_user[user] * lambda_I
        X = np.linalg.solve(A, V)
        updated_user_features[:, user] = np.copy(X.T)
    return updated_user_features

def update_item_feature(
        train, user_features, lambda_item,
        nnz_users_per_item, nz_item_userindices):
    """update item feature matrix."""
    """the best lambda is assumed to be nnz_items_per_item[item] * lambda_item"""
    num_item = nnz_users_per_item.shape[0]
    num_feature = user_features.shape[0]
    lambda_I = lambda_item * sp.eye(num_feature)
    updated_item_features = np.zeros((num_feature, num_item))

    for item, users in nz_item_userindices:
        # extract the columns corresponding to the prediction for given user
        M = user_features[:, users]
        V = M @ train[item, users].T
        A = M @ M.T + nnz_users_per_item[item] * lambda_I
        X = np.linalg.solve(A, V)
        updated_item_features[:, item] = np.copy(X.T)
    return updated_item_features

# %%
from helpers import build_index_groups


def ALS(train):
    """Alternating Least Squares (ALS) algorithm."""
    # define parameters
    num_features = 20   # K in the lecture notes
    lambda_user = 0.1
    lambda_item = 0.7
    stop_criterion = 1e-6
    change = 1
    error_list = [0, 0]
    
    # set seed
    np.random.seed(988)

    # init ALS
    user_features, item_features = init_MF(train, num_features)
    
    # get the number of non-zero ratings for each user and item
    nnz_items_per_user, nnz_users_per_item = train.getnnz(axis=0), train.getnnz(axis=1)
    
    # group the indices by row or column index
    nz_train, nz_item_userindices, nz_user_itemindices = build_index_groups(train)

    # run ALS
    print("\nstart the ALS algorithm...")
    while change > stop_criterion:
        # update user feature & item feature
        user_features = update_user_feature(
            train, item_features, lambda_user,
            nnz_items_per_user, nz_user_itemindices)
        item_features = update_item_feature(
            train, user_features, lambda_item,
            nnz_users_per_item, nz_item_userindices)

        error = compute_error(train, user_features, item_features, nz_train)
        print("RMSE on training set: {}.".format(error))
        error_list.append(error)
        change = np.fabs(error_list[-1] - error_list[-2])

    
    return user_features,item_features

# %%
user_features_als,item_features_als=ALS(ratings)
prediction_als=prediction(test_submission,item_features_als,user_features_als)
# Out:
# start the ALS algorithm...
# RMSE on training set: 2.065063021490569.
# RMSE on training set: 1.273463815376106.
# RMSE on training set: 1.1449053870831276.
# RMSE on training set: 1.0939015808006096.
# RMSE on training set: 1.0684238701680566.
# RMSE on training set: 1.0539746318308731.
# RMSE on training set: 1.0450942951421904.
# RMSE on training set: 1.039332330498928.
# RMSE on training set: 1.035449129888575.
# RMSE on training set: 1.0327601516258906.
# RMSE on training set: 1.0308611744052287.
# RMSE on training set: 1.0295006923357326.
# RMSE on training set: 1.0285156463572684.
# RMSE on training set: 1.0277968413905214.
# RMSE on training set: 1.0272692744283838.
# RMSE on training set: 1.0268804005494088.
# RMSE on training set: 1.0265928420890558.
# RMSE on training set: 1.0263796971005599.
# RMSE on training set: 1.026221429358883.
# RMSE on training set: 1.0261037548976675.
# RMSE on training set: 1.0260161761245978.
# RMSE on training set: 1.0259509481651852.
# RMSE on training set: 1.0259023403447758.
# RMSE on training set: 1.0258661030621323.
# RMSE on training set: 1.0258390798322936.
# RMSE on training set: 1.0258189232220234.
# RMSE on training set: 1.0258038858712142.
# RMSE on training set: 1.0257926662012244.
# RMSE on training set: 1.0257842941895956.
# RMSE on training set: 1.0257780466337145.
# RMSE on training set: 1.0257733841931593.
# RMSE on training set: 1.0257699045596336.
# RMSE on training set: 1.02576730759269.
# RMSE on training set: 1.0257653693469857.
# RMSE on training set: 1.0257639227141135.
# RMSE on training set: 1.0257628429892849.
# RMSE on training set: 1.0257620371065734.
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
OUTPUT_PATH = 'ALS_20.csv' 

prediction_als=np.round(prediction_als.flatten())
a=np.where(prediction_als>5)[0]
prediction_als[a]=5

submission(path_test,prediction_als,OUTPUT_PATH)

# %% [markdown]
# ## Pytorch

# %%
import pandas as pd
import torch
from spotlight.interactions import Interactions
from spotlight.factorization.explicit import ExplicitFactorizationModel
from spotlight.cross_validation import random_train_test_split
from spotlight.evaluation import rmse_score
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
from helpers import *
LOSS = 'regression'  # Our chosen loss
K = 20  # Latent dimension of our matrix factorization
NB_EPOCHS = 30  # Number of times we go through our training set
BATCH_SIZE = 32  # The batch size of our optimization algorithm
L2 = 1e-5  # Our lambda ridge penalization
GAMMA = 1e-4  # Our optimization learning rate

# Loading train data
print("---------LOADING DATA-----------")
raw_data_train = pd.read_csv('data_train.csv')
raw_data_output = pd.read_csv('sampleSubmission.csv')

print("---------PREPROCESSING DATA-----------")
df_input = split_(raw_data_train, column='Id')
df_output = split_(raw_data_output, column='Id')
input_interaction = create_input(df_input['userid'].values,
                                               df_input['movieid'].values,
                                               df_input['rating'].values)

output_interaction = create_input(df_output['userid'].values,
                                                df_output['movieid'].values,
                                                df_output['rating'].values)

print("---------TRAINING THE MODEL-----------")
model = create_model(loss=LOSS, k=K, number_epochs=NB_EPOCHS, batch_size=BATCH_SIZE, l2_penal=L2, gamma=GAMMA)
model = train_model(model, input_interaction)
print("---------CREATING THE SUBMISSION-----------")
df_submission = create_output_df(y_predictions=predict_output(model, output_interaction), test_df=raw_data_output)
create_submission_pd(df_submission)
# Out:
# ---------LOADING DATA-----------
# ---------PREPROCESSING DATA-----------
# ---------TRAINING THE MODEL-----------
# Epoch 0: loss 11.808978693339691
# Epoch 1: loss 2.221023114873733
# Epoch 2: loss 1.0749866440719946
# Epoch 3: loss 1.014201435913752
# Epoch 4: loss 1.0036618863256996
# Epoch 5: loss 1.000469624169046
# Epoch 6: loss 0.9990616741358778
# Epoch 7: loss 0.9976488795650446
# Epoch 8: loss 0.9965754535949215
# Epoch 9: loss 0.995116572694359
# Epoch 10: loss 0.9937046261423974
# Epoch 11: loss 0.9917810907779826
# Epoch 12: loss 0.9894441019312613
# Epoch 13: loss 0.9870301735669972
# Epoch 14: loss 0.9839572431582418
# Epoch 15: loss 0.9809411778465155
# Epoch 16: loss 0.9776719151656257
# Epoch 17: loss 0.9741851131667383
# Epoch 18: loss 0.9706778684514153
# Epoch 19: loss 0.9672847675307024
# Epoch 20: loss 0.9641072391291098
# Epoch 21: loss 0.9607400285842037
# Epoch 22: loss 0.9570136881005097
# Epoch 23: loss 0.9534914778277003
# Epoch 24: loss 0.9492016573743824
# Epoch 25: loss 0.9450947575104222
# Epoch 26: loss 0.94088751644949
# Epoch 27: loss 0.9364620140400886
# Epoch 28: loss 0.931986222458192
# Epoch 29: loss 0.9276498471250499
# ---------CREATING THE SUBMISSION-----------

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
import pandas as pd
from surprise import Reader
from helpers import *

# Load the data.
print("---------LOADING DATA-----------")
data_train = pd.read_csv('data_train.csv')
data_output = pd.read_csv('sampleSubmission.csv')

print("---------PREPROCESSING DATA-----------")
df_input = split_(data_train, column='Id')
df_output = split_(data_output, column='Id')
reader = Reader(rating_scale=(1, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df_input[['userid', 'movieid', 'rating']], reader)
# Use the famous SVD algorithm.
algo = SVD()

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# ---------LOADING DATA-----------
# ---------PREPROCESSING DATA-----------
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0277  1.0284  1.0277  1.0292  1.0238  1.0274  0.0019
# MAE (testset)     0.8197  0.8203  0.8204  0.8219  0.8180  0.8201  0.0013
# Fit time          91.58   91.77   94.90   92.62   92.40   92.65   1.19
# Test time         3.77    3.92    4.61    3.71    3.56    3.92    0.37
# {'test_rmse': array([1.02774782, 1.02836132, 1.02767626, 1.02919419, 1.02378757]),
#  'test_mae': array([0.81973704, 0.82026217, 0.82037513, 0.82191   , 0.81800344]),
#  'fit_time': (91.57523536682129,
#   91.76902413368225,
#   94.89803957939148,
#   92.61508774757385,
#   92.40403032302856),
#  'test_time': (3.771996021270752,
#   3.9249796867370605,
#   4.612553119659424,
#   3.705843925476074,
#   3.56200909614563)}

# %%
from surprise.model_selection import GridSearchCV
data = Dataset.load_from_df(df_input[['userid', 'movieid', 'rating']], reader)
param_grid = {'n_epochs': [5,10], 'lr_all': [0.005,0.009],
              'reg_all': [0.4,0.2]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\IPython\core\interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-15-fd44323cb2b8>", line 7, in <module>
#     gs.fit(data)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\surprise\model_selection\search.py", line 90, in fit
#     verbose=self.joblib_verbose)(delayed_list)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\parallel.py", line 1007, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\parallel.py", line 835, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\parallel.py", line 754, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\_parallel_backends.py", line 209, in apply_async
#     result = ImmediateResult(func)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\_parallel_backends.py", line 590, in __init__
#     self.results = batch()
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\parallel.py", line 256, in __call__
#     for func, args, kwargs in self.items]
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\joblib\parallel.py", line 256, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\surprise\model_selection\validation.py", line 164, in fit_and_score
#     algo.fit(trainset)
#   File "surprise/prediction_algorithms/matrix_factorization.pyx", line 155, in surprise.prediction_algorithms.matrix_factorization.SVD.fit
#   File "surprise/prediction_algorithms/matrix_factorization.pyx", line 231, in surprise.prediction_algorithms.matrix_factorization.SVD.sgd
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\surprise\trainset.py", line 189, in all_ratings
#     yield u, i, r
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\IPython\core\interactiveshell.py", line 2034, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\IPython\core\ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\IPython\core\ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\inspect.py", line 1450, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\site-packages\IPython\core\ultratb.py", line 185, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "c:\users\lamyae\appdata\local\continuum\anaconda3\envs\projectml2\lib\tokenize.py", line 452, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
from surprise import SVDpp , SlopeOne ,NMF , NormalPredictor , KNNBaseline , KNNBasic , KNNWithMeans ,KNNWithZScore , BaselineOnly , CoClustering
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    print("_____step1____")
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# _____step1____
# _____step1____
# _____step1____
# _____step1____
# _____step1____
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# _____step1____
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# _____step1____
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# _____step1____
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# _____step1____
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# _____step1____
# _____step1____
#                  test_rmse     fit_time   test_time
# Algorithm
# BaselineOnly      0.999947     3.832720    6.362024
# SlopeOne          1.001506     6.460053   60.607916
# KNNBaseline       1.011970   120.580732  847.633581
# CoClustering      1.013733    29.899863    6.541970
# NMF               1.014375    77.733584    5.737661
# KNNWithMeans      1.024882   111.466288  792.832491
# SVDpp             1.024894  1674.849502   69.053940
# KNNWithZScore     1.026487   115.130776  851.329665
# KNNBasic          1.031897   100.597629  715.553122
# SVD               1.032499    74.655963    7.463581
# NormalPredictor   1.483146     2.329978    7.345178

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
import pandas as pd
from surprise import Reader
from helpers import *
from surprise import SVDpp , SlopeOne ,NMF , NormalPredictor , KNNBaseline , KNNBasic , KNNWithMeans ,KNNWithZScore , BaselineOnly , CoClustering
print("---------LOADING DATA-----------")
data_train = pd.read_csv('data_train.csv')
data_output = pd.read_csv('sampleSubmission.csv')

print("---------PREPROCESSING DATA-----------")
df_input = split_(data_train, column='Id')
df_output = split_(data_output, column='Id')
reader = Reader(rating_scale=(1, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df_input[['userid', 'movieid', 'rating']], reader)
print('Using ALS')
bsl_options = {'method': 'als',
               'n_epochs': 5,
               'reg_u': 12,
               'reg_i': 5
               }
algo = BaselineOnly(bsl_options=bsl_options)
cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
# Out:
# ---------LOADING DATA-----------
# ---------PREPROCESSING DATA-----------
# Using ALS
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# {'test_rmse': array([0.99966153, 1.00081319, 1.00009591]),
#  'fit_time': (2.2487738132476807, 3.047178030014038, 2.9119856357574463),
#  'test_time': (5.219197988510132, 4.664770603179932, 5.323895454406738)}
